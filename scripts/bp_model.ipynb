# %% [markdown]
# # Neural Networks Course - LEONARDO H. DE MORAES - Final Project
#
# **Name:** Leonardo H. de Moraes
# **Student ID:** 1711609
#
# **Course:** Neural Networks - Polytechnic Institute of Guarda (IPG)
# **Acronym:** LEI
# **Department:** School of Technology and Management
# **Degree:** Bachelor's
# **Program:** Computer Engineering
# **Academic Year:** 2024/2025
# **Professor:** Noel de Jesus Mendonça Lopes
#
# ---
#
# ## Project Objective
# The goal of this project is to develop predictive models for the exchange rates of the US Dollar (**USD**) and the Japanese Yen (**JPY**) against the Euro (**EUR**). Students will use neural networks to build and compare different models.

# %%
## == Import Libs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dataset_utils.bp_model import BP_ForexPredictor
# Out:
# 2025-05-26 23:20:30.283279: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-26 23:20:30.287697: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-26 23:20:30.299530: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748298030.320935   26726 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748298030.326207   26726 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748298030.342214   26726 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748298030.342233   26726 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748298030.342235   26726 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748298030.342237   26726 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-26 23:20:30.348078: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print('+ == =================================================================== == +')
print('|                          Load and preprocess data                         |')
print('+ == =================================================================== == +')


dataset_path = "../data/dateset/multi_forex_dataset_2015-01-01_to_2025-05-24.csv"
predictor = BP_ForexPredictor(dataset_path)
X_train, y_train, X_test, y_test, df = predictor.load_and_preprocess_data()
# Out:
# + == =================================================================== == +
# |                          Load and preprocess data                         |
# + == =================================================================== == +

# %%
print('+ == =================================================================== == +')
print('|                  Build and traing  Back Propagation model                 |')
print('+ == =================================================================== == +')

predictor.model = predictor.build_model(X_train.shape[1])
print("\n   ↳ Resumo do Modelo:")
predictor.model.summary()

print("\n   ↳ Treinando o modelo...")
history = predictor.train_model(X_train, y_train, X_test, y_test)
# Out:
# + == =================================================================== == +
# |                  Build and traing  Back Propagation model                 |
# + == =================================================================== == +
#
#    ↳ Resumo do Modelo:
# /home/leo-moraes/Documents/leo/IPG/Redes_Neurais/final_work_redes_neurais/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1748298032.598093   26726 cuda_executor.cc:1228] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1748298032.599125   26726 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,050 (47.07 KB)
#  Trainable params: 12,050 (47.07 KB)
#  Non-trainable params: 0 (0.00 B)
#    ↳ Treinando o modelo...
# Epoch 1/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0805 - mae: 0.2212 - val_loss: 0.0584 - val_mae: 0.1945
# Epoch 2/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0106 - mae: 0.0809 - val_loss: 0.0369 - val_mae: 0.1564
# Epoch 3/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0068 - mae: 0.0637 - val_loss: 0.0318 - val_mae: 0.1413
# Epoch 4/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0052 - mae: 0.0560 - val_loss: 0.0326 - val_mae: 0.1334
# Epoch 5/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0041 - mae: 0.0494 - val_loss: 0.0304 - val_mae: 0.1275
# Epoch 6/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0032 - mae: 0.0436 - val_loss: 0.0297 - val_mae: 0.1206
# Epoch 7/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0027 - mae: 0.0400 - val_loss: 0.0313 - val_mae: 0.1172
# Epoch 8/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0361 - val_loss: 0.0324 - val_mae: 0.1158
# Epoch 9/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0020 - mae: 0.0343 - val_loss: 0.0379 - val_mae: 0.1171
# Epoch 10/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017 - mae: 0.0315 - val_loss: 0.0360 - val_mae: 0.1137
# Epoch 11/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0016 - mae: 0.0302 - val_loss: 0.0357 - val_mae: 0.1143
# Epoch 12/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0014 - mae: 0.0282 - val_loss: 0.0376 - val_mae: 0.1159
# Epoch 13/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0013 - mae: 0.0272 - val_loss: 0.0383 - val_mae: 0.1173
# Epoch 14/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mae: 0.0257 - val_loss: 0.0380 - val_mae: 0.1192
# Epoch 15/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mae: 0.0244 - val_loss: 0.0366 - val_mae: 0.1168
# Epoch 16/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.8987e-04 - mae: 0.0239 - val_loss: 0.0349 - val_mae: 0.1156
# Epoch 17/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.1086e-04 - mae: 0.0229 - val_loss: 0.0362 - val_mae: 0.1172
# Epoch 18/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.2302e-04 - mae: 0.0219 - val_loss: 0.0347 - val_mae: 0.1152
# Epoch 19/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.0069e-04 - mae: 0.0215 - val_loss: 0.0354 - val_mae: 0.1174
# Epoch 20/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2956e-04 - mae: 0.0206 - val_loss: 0.0337 - val_mae: 0.1147
# Epoch 21/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.5595e-04 - mae: 0.0196 - val_loss: 0.0352 - val_mae: 0.1184

# %%
print('+ == =================================================================== == +')
print('|                        Predictions for next 5 days                        |')
print('+ == =================================================================== == +')

## == Previsões
rmse_usd, rmse_jpy = predictor.make_predictions(X_test, y_test, df)
print(f"\n  ↳ Performance do Modelo:")
print(f"    ↳ RMSE USD/EUR: {rmse_usd:.6f}")
print(f"    ↳ RMSE JPY/EUR: {rmse_jpy:.6f}")


## == Plot results
predictor.plot_results(df)



forecast_df = pd.DataFrame({
    'date': predictor.forecast_dates,
    'USD_EUR_pred': predictor.forecast_values[:, 0],
    'JPY_EUR_pred': predictor.forecast_values[:, 1]
})
forecast_df.to_csv('../temp/forex_predictions_enhanced_BP.csv', index=False)
print("\n   ↳ Previsões salvas em 'forex_predictions_enhanced.csv'")
# Out:
# + == =================================================================== == +
# |                        Predictions for next 5 days                        |
# + == =================================================================== == +
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
#   ↳ Performance do Modelo:
#     ↳ RMSE USD/EUR: 0.017207
#     ↳ RMSE JPY/EUR: 0.000768
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Previsões para os próximos 5 dias:
#       Data  USD/EUR_Previsto  JPY/EUR_Previsto
# 2025-05-24          0.875142          0.007358
# 2025-05-25          0.874189          0.007374
# 2025-05-26          0.873388          0.007249
# 2025-05-27          0.874350          0.007252
# 2025-05-28          0.875978          0.007273
#
# ======================================================================
#    ↳ Previsões salvas em 'forex_predictions_enhanced.csv'
